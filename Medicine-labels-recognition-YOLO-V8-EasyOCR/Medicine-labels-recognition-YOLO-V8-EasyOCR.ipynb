# %%
# !git clone https://github.com/Arijit1080/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR.git
# Out:
# Cloning into 'Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 135 (delta 7), reused 40 (delta 6), pack-reused 94
# Receiving objects: 100% (135/135), 14.74 MiB | 33.99 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
# %cd /kaggle/working/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR
# Out:
# /kaggle/working/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR

# %%
#Download the dataset
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="TphzavQiO6p5RTKTOv24")
project = rf.workspace("mochoye").project("license-plate-detector-ogxxg")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 1.9 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.5/247.5 kB 4.7 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.1 MB/s eta 0:00:00
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=c2983e962677cf37e09347162e9c5b720a229a953d0530ed84357dceefa7eb24
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built antlr4-python3-runtime
# ...

# %%
#Change data.yaml file
#Transfer data from input to working
import shutil
import os

# Define the source path of your dataset file
source_file_path = '/kaggle/input/datayaml2/data.yaml'

# Define the destination path where you want to move the dataset
destination_file_path = '/kaggle/working/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR/License-Plate-Detector-2/data.yaml'

# Move the dataset file to the working directory
shutil.copyfile(source_file_path, destination_file_path)

# Verify that the file has been moved successfully
if os.path.exists(destination_file_path):
    print("Dataset file has been uploaded to /kaggle/working successfully.")
else:
    print("Failed to upload the dataset file.")
# Out:
# Dataset file has been uploaded to /kaggle/working successfully.

# %%
# !python /kaggle/working/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR/ultralytics/yolo/v8/detect/train.py model=yolov8n.pt data=/kaggle/working/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR/License-Plate-Detector-2/data.yaml epochs=200
# Out:
# ...
# 100%|██████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 75.1MB/s]
#
# ...

# %%
# !python /kaggle/working/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR/predictWithOCR.py model='/kaggle/working/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR/runs/detect/train2/weights/best.pt' source='/kaggle/input/car-number-plate-video/Traffic Control CCTV.mp4'
# Out:
# 2024-06-14 08:40:55.481916: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-14 08:40:55.481974: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-14 08:40:55.483660: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# video 1/1 (1/1800) /kaggle/input/car-number-plate-video/Traffic Control CCTV.mp4: 384x640 78.7ms
# ...

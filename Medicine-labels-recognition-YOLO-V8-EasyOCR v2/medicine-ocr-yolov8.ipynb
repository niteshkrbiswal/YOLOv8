# %%
# !git clone https://github.com/niteshkrbiswal/YOLOv8.git
# Out:
# Cloning into 'YOLOv8'...
# remote: Enumerating objects: 145, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 145 (delta 32), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (145/145), 34.96 MiB | 29.44 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# %cd /kaggle/working/YOLOv8/Medicine-labels-recognition-YOLO-V8-EasyOCR
# Out:
# /kaggle/working/YOLOv8/Medicine-labels-recognition-YOLO-V8-EasyOCR

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="TphzavQiO6p5RTKTOv24")
project = rf.workspace("medicinelabelnitesh").project("project1-o0nvs")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python-headless' candidate (version 4.8.0.74 at https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/opencv-python-headless/) (requires-python:>=3.6))
# Reason for being yanked: deprecated, use 4.8.0.76
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 2.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 20.0 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: opencv-python-headless
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 1.7 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.5/247.5 kB 4.1 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.4 MB/s eta 0:00:00
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=d0731cb25d56c1995c6a28ee65a109c2fdcf0ab76ea9a275d6121fa864801878
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built antlr4-python3-runtime
# ...

# %%
#Change data.yaml file
#Transfer data from input to working
import shutil
import os

# Define the source path of your dataset file
source_file_path = '/kaggle/input/dataset1/data.yaml'

# Define the destination path where you want to move the dataset
destination_file_path = '/kaggle/working/YOLOv8/Medicine-labels-recognition-YOLO-V8-EasyOCR/Project1-2/data.yaml'

# Move the dataset file to the working directory
shutil.copyfile(source_file_path, destination_file_path)

# Verify that the file has been moved successfully
if os.path.exists(destination_file_path):
    print("Dataset file has been uploaded to /kaggle/working successfully.")
else:
    print("Failed to upload the dataset file.")
# Out:
# Dataset file has been uploaded to /kaggle/working successfully.

# %%
# !python /kaggle/working/YOLOv8/Medicine-labels-recognition-YOLO-V8-EasyOCR/ultralytics/yolo/v8/detect/train.py model=yolov8n.pt data=/kaggle/working/YOLOv8/Medicine-labels-recognition-YOLO-V8-EasyOCR/Project1-2/data.yaml epochs=100
# Out:
# ...
# 100%|██████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 67.0MB/s]
#
# ...

# %%
# !python /kaggle/working/YOLOv8/Medicine-labels-recognition-YOLO-V8-EasyOCR/predictWithOCR.py model='/kaggle/working/YOLOv8/runs/detect/train2/weights/best.pt' source='/kaggle/input/dataset5/flame.jpg'
# Out:
# 2024-06-14 18:55:08.799849: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-14 18:55:08.799919: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-14 18:55:08.801565: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /kaggle/input/dataset5/flame.jpg: 640x544 1 Labels, 82.7ms
# ...
